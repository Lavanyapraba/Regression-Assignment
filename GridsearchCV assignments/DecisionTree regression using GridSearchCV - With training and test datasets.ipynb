# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
input=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
input
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
output=dataset[['charges']]

# %%
output
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input,output,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV


from sklearn.tree import DecisionTreeRegressor

param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'max_features':['sqrt','log2']}

grid=GridSearchCV(DecisionTreeRegressor(),param_grid,n_jobs=-1,cv=5,verbose=3,refit=True)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_predictions=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.012626      0.001347         0.005840        0.001634
# 1        0.009490      0.001145         0.005100        0.001712
# 2        0.008413      0.001374         0.004213        0.001054
# 3        0.006476      0.000526         0.004610        0.000422
# 4        0.010145      0.003053         0.004709        0.000856
# 5        0.007944      0.000918         0.005056        0.001036
# 6        0.008422      0.000485         0.004695        0.000742
# 7        0.008093      0.001496         0.004492        0.000634
# 8        0.033587      0.004741         0.005934        0.001925
# 9        0.026772      0.003690         0.004731        0.000688
# 10       0.031294      0.003352         0.004277        0.000838
# 11       0.024371      0.002185         0.004616        0.000363
# 12       0.008556      0.000899         0.004231        0.001072
# 13       0.009803      0.001722         0.005102        0.000578
# 14       0.009485      0.000002         0.004292        0.000399
# 15       0.006990      0.000894         0.004090        0.000661
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.653274
# 1   {'criterion': 'squared_error', 'max_features':...           0.639246
# 2   {'criterion': 'squared_error', 'max_features':...           0.669332
# 3   {'criterion': 'squared_error', 'max_features':...           0.728585
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.659141
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.616887
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.725393
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.606754
# 8   {'criterion': 'absolute_error', 'max_features'...           0.686251
# 9   {'criterion': 'absolute_error', 'max_features'...           0.605920
# 10  {'criterion': 'absolute_error', 'max_features'...           0.684526
# 11  {'criterion': 'absolute_error', 'max_features'...           0.780238
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.721304
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.648363
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.671897
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.599363
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.628216           0.678170           0.665603
# 1            0.558119           0.522859           0.735399
# 2            0.670601           0.701861           0.718335
# 3            0.587242           0.670141           0.641891
# 4            0.644418           0.748024           0.718821
# 5            0.543297           0.670233           0.725103
# 6            0.642471           0.748644           0.744005
# 7            0.533029           0.674975           0.656060
# 8            0.580786           0.649282           0.735375
# 9            0.620391           0.706828           0.676305
# 10           0.684301           0.633677           0.551106
# 11           0.521570           0.681930           0.730276
# 12           0.592899           0.710046           0.721116
# 13           0.599804           0.683302           0.668089
# 14           0.709057           0.733131           0.739251
# 15           0.562591           0.671122           0.673151
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.720072         0.669067        0.030380                9
# 1            0.667304         0.624586        0.076270               15
# 2            0.619126         0.675851        0.033968                6
# 3            0.618591         0.649290        0.048103               11
# 4            0.706843         0.695450        0.038374                3
# 5            0.655888         0.642282        0.060446               13
# 6            0.609739         0.694050        0.056969                4
# 7            0.580633         0.610290        0.051265               16
# 8            0.759237         0.682186        0.063478                5
# 9            0.744943         0.670877        0.052107                8
# 10           0.675996         0.645921        0.051005               12
# 11           0.659232         0.674649        0.087141                7
# 12           0.756926         0.700458        0.056055                2
# 13           0.678061         0.655524        0.030310               10
# 14           0.701029         0.710873        0.024166                1
# 15           0.648498         0.630945        0.043297               14

# %%
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}: 0.7780898320759736
