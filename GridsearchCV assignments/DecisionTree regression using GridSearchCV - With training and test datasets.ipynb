# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
input=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
input
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
output=dataset[['charges']]

# %%
output
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input,output,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV


from sklearn.tree import DecisionTreeRegressor

param_grid={'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'max_features':['sqrt','log2',None]}

grid=GridSearchCV(DecisionTreeRegressor(),param_grid,n_jobs=-1,cv=5,verbose=3,refit=True)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_predictions=grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.007919      0.001759         0.004112        0.001235
# 1        0.006116      0.001577         0.002608        0.000367
# 2        0.007020      0.002261         0.003909        0.001641
# 3        0.005812      0.001940         0.003812        0.000741
# 4        0.007812      0.001639         0.004217        0.001601
# 5        0.006209      0.000970         0.003932        0.001454
# 6        0.005522      0.000643         0.003910        0.000976
# 7        0.005527      0.001096         0.002813        0.000673
# 8        0.005331      0.000414         0.003115        0.000691
# 9        0.005661      0.002276         0.002696        0.000398
# 10       0.007709      0.001720         0.003099        0.001114
# 11       0.006610      0.001475         0.003629        0.001769
# 12       0.019560      0.001003         0.003002        0.000551
# 13       0.016458      0.003358         0.002807        0.001023
# 14       0.018901      0.002499         0.002820        0.000238
# 15       0.014370      0.002031         0.002424        0.000493
# 16       0.028573      0.001484         0.002599        0.000793
# 17       0.022644      0.002367         0.003703        0.001546
# 18       0.006221      0.000680         0.002199        0.000397
# 19       0.006721      0.000975         0.002198        0.000407
# 20       0.006818      0.002301         0.002806        0.000689
# 21       0.005817      0.001316         0.002802        0.000750
# 22       0.008515      0.001257         0.003004        0.000545
# 23       0.004908      0.000487         0.002211        0.000822
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               None           best
# 11    friedman_mse               None         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.800007
# 1   {'criterion': 'squared_error', 'max_features':...           0.552055
# 2   {'criterion': 'squared_error', 'max_features':...           0.706041
# 3   {'criterion': 'squared_error', 'max_features':...           0.574963
# 4   {'criterion': 'squared_error', 'max_features':...           0.725682
# 5   {'criterion': 'squared_error', 'max_features':...           0.643913
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.708078
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.727836
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.670073
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.384422
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.747815
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.720875
# 12  {'criterion': 'absolute_error', 'max_features'...           0.664350
# 13  {'criterion': 'absolute_error', 'max_features'...           0.670486
# 14  {'criterion': 'absolute_error', 'max_features'...           0.668151
# 15  {'criterion': 'absolute_error', 'max_features'...           0.449666
# 16  {'criterion': 'absolute_error', 'max_features'...           0.756144
# 17  {'criterion': 'absolute_error', 'max_features'...           0.746651
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.742531
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.682268
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.498452
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.740530
# 22  {'criterion': 'poisson', 'max_features': None,...           0.708833
# 23  {'criterion': 'poisson', 'max_features': None,...           0.762510
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.627483           0.692064           0.455551
# 1            0.474011           0.638829           0.587329
# 2            0.508607           0.754181           0.629493
# 3            0.647959           0.594013           0.532797
# 4            0.562338           0.772678           0.634813
# 5            0.625343           0.710322           0.529338
# 6            0.609255           0.675200           0.615341
# 7            0.588074           0.527274           0.507875
# 8            0.685349           0.586651           0.684046
# 9            0.637404           0.615922           0.655910
# 10           0.594472           0.768665           0.622088
# 11           0.563828           0.719092           0.565407
# 12           0.648440           0.657276           0.508627
# 13           0.545967           0.727961           0.527084
# 14           0.550832           0.470218           0.381351
# 15           0.503798           0.690104           0.587125
# 16           0.623996           0.614084           0.501989
# 17           0.674407           0.677878           0.568398
# 18           0.525552           0.615874           0.607463
# 19           0.543580           0.561248           0.506163
# 20           0.381319           0.487156           0.643871
# 21           0.682020           0.585627           0.583553
# 22           0.584598           0.687241           0.567818
# 23           0.620772           0.716816           0.596261
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.603623         0.635746        0.112892               10
# 1            0.493551         0.549155        0.060408               20
# 2            0.651541         0.649973        0.082957                5
# 3            0.604479         0.590842        0.037629               17
# 4            0.659892         0.671080        0.072896                3
# 5            0.665331         0.634849        0.059884               11
# 6            0.586550         0.638885        0.045338                7
# 7            0.528152         0.575842        0.080628               19
# 8            0.612639         0.647752        0.040485                6
# 9            0.380121         0.534756        0.125152               23
# 10           0.668407         0.680289        0.068210                1
# 11           0.592354         0.632311        0.072301               14
# 12           0.583430         0.612425        0.059362               15
# 13           0.533504         0.601001        0.082457               16
# 14           0.639592         0.542029        0.106280               21
# 15           0.478721         0.541883        0.087132               22
# 16           0.666769         0.632596        0.082349               13
# 17           0.678079         0.669082        0.057168                4
# 18           0.672235         0.632731        0.072148               12
# 19           0.643387         0.587329        0.065327               18
# 20           0.608502         0.523860        0.093678               24
# 21           0.595596         0.637465        0.063173                8
# 22           0.633003         0.636299        0.055190                9
# 23           0.679390         0.675150        0.060936                2

# %%
print("The R_score value for the best parameter{}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter{'criterion': 'friedman_mse', 'max_features': None, 'splitter': 'best'}: 0.6968850136522804
