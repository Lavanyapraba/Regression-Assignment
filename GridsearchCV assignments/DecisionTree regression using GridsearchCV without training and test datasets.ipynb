# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
input=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
input
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
output=dataset[['charges']]

# %%
output
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

input=sc.fit_transform(input)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid= {'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'max_features':['sqrt','log2']}

grid=GridSearchCV(DecisionTreeRegressor(),param_grid,n_jobs=-1,verbose=3,refit=True)

# %%
grid.fit(input,output)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_predictions=grid.predict(input)

from sklearn.metrics import r2_score

r_score=r2_score(output,grid_predictions)

# %%
re=grid.cv_results_

# %%
Table= pd.DataFrame.from_dict(re)

# %%
Table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009561      0.000617         0.004112        0.000406
# 1        0.010903      0.002834         0.006873        0.004435
# 2        0.009427      0.000531         0.003531        0.000403
# 3        0.009932      0.001003         0.005457        0.001496
# 4        0.012163      0.003533         0.004529        0.001639
# 5        0.008171      0.000996         0.004498        0.000681
# 6        0.010562      0.001875         0.005258        0.001133
# 7        0.008136      0.000767         0.005825        0.003576
# 8        0.039023      0.003306         0.004106        0.002086
# 9        0.028899      0.004000         0.004077        0.000421
# 10       0.033239      0.004248         0.003472        0.000897
# 11       0.029939      0.003945         0.004253        0.001349
# 12       0.009438      0.000847         0.003703        0.000940
# ...

# %%
print("The R_score value for the best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}: 0.998667156135576

# %%
Future_Prediction=grid.predict([[56,38,2,0,0]])

print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[36580.28216]

# %%
import pickle
filename="Best_gridsearchcvmodel_DecisionTree_Withouttest&trainingdata"
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("Best_gridsearchcvmodel_DecisionTree_Withouttest&trainingdata",'rb'))
Charges=loaded_model.predict([[53,38,2,0,0]])

# %%
Charges
# Out:
# array([36580.28216])
