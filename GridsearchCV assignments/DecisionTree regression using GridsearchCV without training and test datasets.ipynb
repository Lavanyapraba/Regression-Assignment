# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
input=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
input
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
output=dataset[['charges']]

# %%
output
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

input=sc.fit_transform(input)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid= {'criterion':['squared_error','friedman_mse','absolute_error','poisson'],'splitter':['best','random'],'max_features':['sqrt','log2',None]}

grid=GridSearchCV(DecisionTreeRegressor(),param_grid,n_jobs=-1,verbose=3,refit=True)

# %%
grid.fit(input,output)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
grid_predictions=grid.predict(input)

from sklearn.metrics import r2_score

r_score=r2_score(output,grid_predictions)

# %%
re=grid.cv_results_

# %%
Table= pd.DataFrame.from_dict(re)

# %%
Table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009416      0.002070         0.004315        0.001932
# 1        0.006815      0.002304         0.003897        0.001244
# 2        0.007713      0.001782         0.003826        0.000942
# 3        0.005996      0.001378         0.003208        0.001032
# 4        0.008206      0.000731         0.002995        0.000702
# 5        0.008828      0.002016         0.002710        0.000597
# 6        0.006714      0.001627         0.004814        0.001901
# 7        0.006210      0.000863         0.003506        0.000949
# 8        0.007323      0.001696         0.002903        0.000674
# 9        0.005317      0.000938         0.004023        0.000714
# 10       0.009433      0.000372         0.003404        0.000913
# 11       0.006514      0.000544         0.004122        0.001380
# 12       0.033486      0.003867         0.003021        0.000645
# 13       0.020779      0.005494         0.005010        0.002686
# 14       0.031406      0.002434         0.002794        0.000747
# 15       0.027382      0.003883         0.002802        0.000674
# 16       0.048299      0.006974         0.003402        0.001467
# 17       0.036755      0.004556         0.004019        0.001129
# 18       0.009937      0.001567         0.002903        0.000661
# 19       0.006827      0.000938         0.002798        0.000929
# 20       0.007809      0.000596         0.002807        0.000601
# 21       0.007718      0.002338         0.003109        0.000976
# 22       0.014857      0.004498         0.003204        0.001215
# 23       0.006996      0.001308         0.003307        0.000993
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4    squared_error               None           best
# 5    squared_error               None         random
# 6     friedman_mse               sqrt           best
# 7     friedman_mse               sqrt         random
# 8     friedman_mse               log2           best
# 9     friedman_mse               log2         random
# 10    friedman_mse               None           best
# 11    friedman_mse               None         random
# 12  absolute_error               sqrt           best
# 13  absolute_error               sqrt         random
# 14  absolute_error               log2           best
# 15  absolute_error               log2         random
# 16  absolute_error               None           best
# 17  absolute_error               None         random
# 18         poisson               sqrt           best
# 19         poisson               sqrt         random
# 20         poisson               log2           best
# 21         poisson               log2         random
# 22         poisson               None           best
# 23         poisson               None         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.800377
# 1   {'criterion': 'squared_error', 'max_features':...           0.583542
# 2   {'criterion': 'squared_error', 'max_features':...           0.643879
# 3   {'criterion': 'squared_error', 'max_features':...           0.659824
# 4   {'criterion': 'squared_error', 'max_features':...           0.728504
# 5   {'criterion': 'squared_error', 'max_features':...           0.706202
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.752417
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.596163
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.697007
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.639709
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.722044
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.690880
# 12  {'criterion': 'absolute_error', 'max_features'...           0.747365
# 13  {'criterion': 'absolute_error', 'max_features'...           0.662142
# 14  {'criterion': 'absolute_error', 'max_features'...           0.640879
# 15  {'criterion': 'absolute_error', 'max_features'...           0.767691
# 16  {'criterion': 'absolute_error', 'max_features'...           0.736972
# 17  {'criterion': 'absolute_error', 'max_features'...           0.689797
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.711596
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.608645
# 20  {'criterion': 'poisson', 'max_features': 'log2...           0.734705
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.677197
# 22  {'criterion': 'poisson', 'max_features': None,...           0.742696
# 23  {'criterion': 'poisson', 'max_features': None,...           0.703338
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.573511           0.638504           0.694740
# 1            0.592853           0.705541           0.659299
# 2            0.618615           0.690472           0.684087
# 3            0.613354           0.641731           0.662042
# 4            0.645486           0.741361           0.723618
# 5            0.558946           0.680743           0.721727
# 6            0.596303           0.673158           0.753487
# 7            0.666933           0.787939           0.632663
# 8            0.539388           0.758298           0.685220
# 9            0.616944           0.744040           0.718220
# 10           0.648944           0.729082           0.744085
# 11           0.600657           0.642192           0.699543
# 12           0.592946           0.684933           0.693279
# 13           0.067024           0.613780           0.725446
# 14           0.648732           0.748041           0.685705
# 15           0.534685           0.689934           0.698140
# 16           0.641262           0.716791           0.730128
# 17           0.637725           0.763179           0.752058
# 18           0.423870           0.776936           0.751490
# 19           0.666926           0.711138           0.757797
# 20           0.616514           0.748451           0.718997
# 21           0.630824           0.729862           0.697004
# 22           0.662421           0.775388           0.713634
# 23           0.554558           0.705160           0.690630
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.702496         0.681926        0.075176               11
# 1            0.683365         0.644920        0.048658               23
# 2            0.743168         0.676044        0.042688               17
# 3            0.727385         0.660867        0.037552               22
# 4            0.671990         0.702192        0.036914                6
# 5            0.684533         0.670430        0.057698               19
# 6            0.536389         0.662351        0.085748               21
# 7            0.698594         0.676458        0.065382               16
# 8            0.713139         0.678610        0.073902               14
# 9            0.603382         0.664459        0.056257               20
# 10           0.683945         0.705620        0.034588                5
# 11           0.721452         0.670945        0.043665               18
# 12           0.706376         0.684980        0.050772                9
# 13           0.725889         0.558856        0.249494               24
# 14           0.767057         0.698083        0.051214                7
# 15           0.728866         0.683863        0.079432               10
# 16           0.765047         0.718040        0.041498                2
# 17           0.712755         0.711103        0.045233                4
# 18           0.744858         0.681750        0.130614               12
# 19           0.643203         0.677542        0.052169               15
# 20           0.741828         0.712099        0.048786                3
# 21           0.751709         0.697319        0.042057                8
# 22           0.712575         0.721343        0.037376                1
# 23           0.749490         0.680635        0.066111               13

# %%
print("The R_score value for the best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}: 0.998667156135576

# %%
import pickle
filename="Best_gridsearchcvmodel_DecisionTree_Withouttest&trainingdata.sav"
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open(filename,'rb'))
preinput=sc.transform([[53,38,2,0,0]])
Charges=loaded_model.predict(preinput)
# Out:
# C:\Users\91805\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
Charges
# Out:
# array([12646.207])
