# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
input=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
input
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
output=dataset[['charges']]

# %%
output
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(input,output,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR

param_grid={'kernel':['linear','poly','rbf','sigmoid'],'C':[10,100,1000,2000,3000],'gamma':['scale','auto']}

grid=GridSearchCV(SVR(),param_grid,refit=True,verbose=3,n_jobs=-1,cv=5)

grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# C:\Users\91805\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              verbose=3)

# %%
GridSearchCV(estimator=SVR(),n_jobs=-1,verbose=3,param_grid={'kernel':['linear','poly','rbf','sigmoid'],'C':[10,100,1000,2000,3000],'gamma':['scale','auto']})

re=grid.cv_results_


grid_predictions=grid.predict(x_test)

from sklearn.metrics import r2_score
r_score=r2_score(y_test,grid_predictions)

print("The R_score value for the best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for the best parameter {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}: 0.8598930084494356

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.081849      0.004981         0.012116        0.001064      10
# 1        0.074421      0.008697         0.013511        0.002076      10
# 2        0.086721      0.001849         0.042685        0.002367      10
# 3        0.093578      0.010376         0.015115        0.001511      10
# 4        0.066924      0.006286         0.010559        0.000650      10
# 5        0.070733      0.011889         0.011073        0.000667      10
# 6        0.072872      0.003301         0.038462        0.001705      10
# 7        0.084297      0.007199         0.013525        0.001326      10
# 8        0.086247      0.008861         0.011781        0.002319     100
# 9        0.084539      0.022909         0.013104        0.002299     100
# 10       0.072121      0.006313         0.036991        0.003099     100
# 11       0.086352      0.005480         0.015419        0.002159     100
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
Children_input=float(input("Children:"))
Sex_male_input=int(input("Sex male 0 or 1:"))
smoker_yes_input=int(input("smoker yes 0 or 1:"))
